# %%
from pybliometrics.scopus import AuthorRetrieval

# %%
authors = [
  55342333800, # Sander
  24344046200, # Maarten
  36695851100, # Simeon
  35751118200, # Oded
  57568162000, # Francisco
  58288387600, # Lucas
  57196345277, # Yiru
  57694437300, # Nicholas
]

# %%
documents = []

for author_id in authors:
  author = AuthorRetrieval(author_id)
  author_docs = author.get_documents()
  documents.extend(author_docs)

# %%
# remove duplicates
documents = list(set(documents))
len(documents)

# filter and sort by date
documents = list(filter(lambda x: x.coverDate > '2020-01-01', documents))
documents = sorted(documents, key=lambda x: x.coverDate, reverse=True)
# Out:
# 381

# %%
print(documents[0])
# Out:
# Document(eid='2-s2.0-85169296938', doi='10.1016/j.trc.2023.104289', pii='S0968090X23002784', pubmed_id=None, title='Inferring vehicle spacing in urban traffic from trajectory data', subtype='ar', subtypeDescription='Article', creator='Jiao Y.', afid='60118020;60117886', affilname='Department of Transport &amp; Planning, TU Delft;Faculteit Techniek, Bestuur en Management, TU Delft', affiliation_city='Delft;Delft', affiliation_country='Netherlands;Netherlands', author_count='4', author_names='Jiao, Yiru;Calvert, Simeon C.;van Cranenburgh, Sander;van Lint, Hans', author_ids='57196345277;36695851100;55342333800;57311504100', author_afids='60118020-60117886;60118020;60117886;60118020', coverDate='2023-10-01', coverDisplayDate='October 2023', publicationName='Transportation Research Part C: Emerging Technologies', issn='0968090X', source_id='20893', eIssn=None, aggregationType='Journal', volume='155', issueIdentifier=None, article_number='104289', pageRange=None, description='This study presents a new method to infer the average two-dimensional (2D) spacing between interacting vehicles in urban traffic from trajectory data. In this context, 2D spacing reflects the amount of road space consumed by pairs of interacting vehicles, and is related to 2D density at the macroscopic level. Due to complex interaction and conflicts in urban traffic, the inherent assumptions in traditional traffic flow models, such as unidirectional flow and homogeneity, are often violated. Such violation challenges direct measurement of urban vehicle spacing. The proposed method addresses this challenge by focusing on the relative movement between interacting vehicles and aggregating the accumulated presence of vehicles in similar scenarios. We apply the method to a large-scale urban trajectory dataset called pNEUMA, and validate the consistency of the method through bootstrapping. By applying the method we obtain a new empirical relation between the average 2D spacing and the relative speeds between interacting vehicles. There are similarities between this empirical relation with the classical Fundamental Diagram of traffic flow in terms of shape and interpretation, and so we term it the “interaction Fundamental Diagram” (iFD). However, there are also key differences. The iFD does not represent steady-state (homogeneous and stationary) longitudinal behaviour; it describes the average amount of road space needed for vehicle interactions at different relative speeds. We believe these iFD relations contribute to understanding vehicle interaction in urban traffic, and can offer new insights for designing safer and more efficient urban intersections.', authkeywords='Fundamental Diagram | Two-dimensional spacing | Urban traffic | Vehicle interaction', citedby_count=0, openaccess=1, freetoread='publisherhybridgold', freetoreadLabel='Hybrid Gold', fund_acr='TU Delft', fund_no='undefined', fund_sponsor='Technische Universiteit Delft')

# %%
html = '<ul class="publications">'

for doc in documents:
  html += f'''
  <li class="publication-list-item">
    <div class="publication-title"><a href="https://doi.org/{doc.doi}">{doc.title}</a></div>
    <div>{doc.author_names.replace(';', ', ')}</div>
    <div><b class="journal-name">{doc.publicationName}</b>, {doc.coverDate[:4]}</div>
  </li>'''

html += '</ul>'

print(html)
# Out:
# <ul class="publications">
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2023.104289">Inferring vehicle spacing in urban traffic from trajectory data</a></div>
#     <div>Jiao, Yiru, Calvert, Simeon C., van Cranenburgh, Sander, van Lint, Hans</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cie.2023.109577">Optimizing public transport transfers by integrating timetable coordination and vehicle scheduling</a></div>
#     <div>Liu, Tao, Ji, Wen, Gkiotsalitis, Konstantinos, Cats, Oded</div>
#     <div><b class="journal-name">Computers and Industrial Engineering</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.rtbm.2023.101021">Travel choices in (e-)moped sharing systems: Estimating explanatory variables and the value of ride fee savings</a></div>
#     <div>Hoobroeckx, Tom, Cats, Oded, Shelat, Sanmay, Molin, Eric</div>
#     <div><b class="journal-name">Research in Transportation Business and Management</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tbs.2023.100616">An instance-based learning approach for evaluating the perception of ride-hailing waiting time variability</a></div>
#     <div>Geržinič, Nejc, Cats, Oded, van Oort, Niels, Hoogendoorn-Lanser, Sascha, Bierlaire, Michel, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Travel Behaviour and Society</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tre.2023.103265">An exact optimization method for coordinating the arrival times of urban rail lines at a common corridor</a></div>
#     <div>Gkiotsalitis, K., Cats, O., Liu, T., Bult, J. M.</div>
#     <div><b class="journal-name">Transportation Research Part E: Logistics and Transportation Review</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2023.100427">NP4VTT: A new software for estimating the value of travel time with nonparametric models</a></div>
#     <div>Hernández, José Ignacio, van Cranenburgh, Sander</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-022-10278-9">Potential of on-demand services for urban travel</a></div>
#     <div>Geržinič, Nejc, van Oort, Niels, Hoogendoorn-Lanser, Sascha, Cats, Oded, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.compenvurbsys.2023.101990">Characterizing residential segregation in cities using intensity, separation, and scale indicators</a></div>
#     <div>Spierenburg, Lucas, van Cranenburgh, Sander, Cats, Oded</div>
#     <div><b class="journal-name">Computers, Environment and Urban Systems</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2023.103688">Modular vehicle routing for combined passenger and freight transport</a></div>
#     <div>Hatzenbühler, Jonas, Jenelius, Erik, Gidófalvi, Gyözö, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tranpol.2023.03.010">Design and classification of tradable mobility credit schemes</a></div>
#     <div>Provoost, Jesper, Cats, Oded, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transport Policy</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tranpol.2023.03.005">Automated Vehicles: Changes in expert opinions over time</a></div>
#     <div>Kroesen, Maarten, Milakis, Dimitris, van Wee, Bert</div>
#     <div><b class="journal-name">Transport Policy</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2023.103642">Measuring activity-based social segregation using public transport smart card data</a></div>
#     <div>Kolkowski, Lukas, Cats, Oded, Dixit, Malvika, Verma, Trivik, Jenelius, Erik, Cebecauer, Matej, Rubensson, Isak Jarlebring</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-022-10270-3">Mitigating bus bunching with real-time crowding information</a></div>
#     <div>Drabicki, Arkadiusz, Kucharski, Rafał, Cats, Oded</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s00146-022-01605-w">Human–machine coordination in mixed traffic as a problem of Meaningful Human Control</a></div>
#     <div>Mecacci, Giulio, Calvert, Simeon C., Santoni de Sio, Filippo</div>
#     <div><b class="journal-name">AI and Society</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.socscimed.2023.115910">Towards machine learning for moral choice analysis in health economics: A literature review and research agenda</a></div>
#     <div>Smeele, Nicholas V.R., Chorus, Caspar G., Schermer, Maartje H.N., de Bekker-Grob, Esther W.</div>
#     <div><b class="journal-name">Social Science and Medicine</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.compenvurbsys.2023.101971">Where are the people? Counting people in millions of street-level images to explore associations between people's urban density and urban characteristics</a></div>
#     <div>Garrido-Valenzuela, Francisco, Cats, Oded, van Cranenburgh, Sander</div>
#     <div><b class="journal-name">Computers, Environment and Urban Systems</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1061/JTEPBS.TEENG-7176">Bus Network Design and Frequency Setting in the Post-COVID-19 Pandemic: The Case of London</a></div>
#     <div>Filgueiras, Manuel, Gkiotsalitis, Konstantinos, Yap, Menno, Cats, Oded, Lobo, António, Ferreira, Sara</div>
#     <div><b class="journal-name">Journal of Transportation Engineering Part A: Systems</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2023.103622">The effect of trust on the choice for crowdshipping services</a></div>
#     <div>Cebeci, Merve Seher, Tapia, Rodrigo Javier, Kroesen, Maarten, de Bok, Michiel, Tavasszy, Lóránt</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2022.100397">Data-driven assisted model specification for complex choice experiments data: Association rules learning and random forests for Participatory Value Evaluation experiments</a></div>
#     <div>Hernandez, Jose Ignacio, van Cranenburgh, Sander, Chorus, Caspar, Mouter, Niek</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.rtbm.2023.100963">Should I stay or should I board? Willingness to wait with real-time crowding information in urban public transport</a></div>
#     <div>Drabicki, Arkadiusz, Cats, Oded, Kucharski, Rafał, Fonzone, Achille, Szarata, Andrzej</div>
#     <div><b class="journal-name">Research in Transportation Business and Management</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-021-10236-x">Travel attitudes or behaviours: Which one changes when they conflict?</a></div>
#     <div>McCarthy, Laura, Delbosc, Alexa, Kroesen, Maarten, de Haas, Mathijs</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/19427867.2023.2192581">On the Relocation Behavior of Ride-sourcing Drivers</a></div>
#     <div>Ashkrof, Peyman, Homem de Almeida Correia, Gonçalo, Cats, Oded, van Arem, Bart</div>
#     <div><b class="journal-name">Transportation Letters</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jpubtr.2023.100064">Evaluating skip-stop policy in urban rail transit systems based on passenger cost</a></div>
#     <div>Peftitsi, Soumela, Jenelius, Erik, Cats, Oded</div>
#     <div><b class="journal-name">Journal of Public Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.3389/fpsyg.2023.1101520">(Mis-)use of standard Autopilot and Full Self-Driving (FSD) Beta: Results from interviews with users of Tesla's FSD Beta</a></div>
#     <div>Nordhoff, Sina, Lee, John D., Calvert, Simeon C., Berge, Siri, Hagenzieker, Marjan, Happee, Riender</div>
#     <div><b class="journal-name">Frontiers in Psychology</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2023.2236240">Integrating ride-hailing services with public transport: a stochastic user equilibrium model for multimodal transport systems</a></div>
#     <div>Liu, Bing, Ji, Yuxiong, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/01441647.2023.2251688">Identifying human mobility patterns using smart card data</a></div>
#     <div>Cats, Oded</div>
#     <div><b class="journal-name">Transport Reviews</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/01441647.2022.2035014">A review of public transport transfer synchronisation at the real-time control phase</a></div>
#     <div>Gkiotsalitis, Konstantinos, Cats, Oded, Liu, Tao</div>
#     <div><b class="journal-name">Transport Reviews</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2021.1987580">Joint optimisation of regular and demand-responsive transit services</a></div>
#     <div>Zhao, Jing, Sun, Sicheng, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2023.2210229">Mobility operator service capacity sharing contract design to risk-pool against network disruptions</a></div>
#     <div>Pantelidis, Theodoros P., Chow, Joseph Y.J., Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2023.2179345">What is the market potential for on-demand services as a train station access mode?</a></div>
#     <div>Geržinič, Nejc, Cats, Oded, van Oort, Niels, Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2021.2005180">Perception of overlap in multi-modal urban transit route choice</a></div>
#     <div>Dixit, Malvika, Cats, Oded, Brands, Ties, van Oort, Niels, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/21680566.2023.2176274">Special issue on “Reliability and resilience of emerging mobility systems”, an editorial note</a></div>
#     <div>Cats, Oded, Derrible, Sybil, Chow, Joseph</div>
#     <div><b class="journal-name">Transportmetrica B</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/LCSYS.2022.3229865">Safety Certification for Stochastic Systems via Neural Barrier Functions</a></div>
#     <div>Mathiesen, Frederik Baymler, Calvert, Simeon C., Laurenti, Luca</div>
#     <div><b class="journal-name">IEEE Control Systems Letters</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11135-023-01625-8">Moral rhetoric in discrete choice models: a Natural Language Processing approach</a></div>
#     <div>Szép, Teodóra, van Cranenburgh, Sander, Chorus, Caspar</div>
#     <div><b class="journal-name">Quality and Quantity</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-023-10387-z">Validation of a multi-modal transit route choice model using smartcard data</a></div>
#     <div>Dixit, Malvika, Cats, Oded, van Oort, Niels, Brands, Ties, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-023-10401-4">The relations between working from home and travel behaviour: a panel analysis</a></div>
#     <div>Faber, R. M., Hamersma, M., Brimaire, J., Kroesen, M., Molin, E. J.E.</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.103560">Exploring attitude-behaviour dynamics during COVID-19: How fear of infection and working from home influence train use and the attitude toward this mode</a></div>
#     <div>Kroesen, Maarten, De Vos, Jonas, Le, Huyen T.K., Ton, Danique</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/03081060.2023.2194874">Ride-pooling adoption, efficiency and level of service under alternative demand, behavioural and pricing settings</a></div>
#     <div>de Ruijter, Arjan, Cats, Oded, Alonso-Mora, Javier, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation Planning and Technology</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-023-10420-1">Public transport crowding valuation in a post-pandemic era</a></div>
#     <div>Yap, Menno, Wong, Howard, Cats, Oded</div>
#     <div><b class="journal-name">Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/19427867.2022.2074697">Herd immunity for traffic safety in mixed automated traffic: what if cars could not crash!?</a></div>
#     <div>Calvert, Simeon C., van Arem, Bart, Lappin, Jane</div>
#     <div><b class="journal-name">Transportation Letters</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1177/00491241231186657">Maximizing Utility or Avoiding Losses? Uncovering Decision Rule-Heterogeneity in Sociological Research with an Application to Neighbourhood Choice</a></div>
#     <div>Liebe, Ulf, van Cranenburgh, Sander, Chorus, Caspar</div>
#     <div><b class="journal-name">Sociological Methods and Research</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jpubtr.2023.100048">Determinants of station-based round-trip bikesharing demand</a></div>
#     <div>Wilkesmann, Florian, Ton, Danique, Schakenbos, Rik, Cats, Oded</div>
#     <div><b class="journal-name">Journal of Public Transportation</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2022.2028929">Evaluating the impact of waiting time reliability on route choice using smart card data</a></div>
#     <div>Shelat, Sanmay, Cats, Oded, van Oort, Niels, van Lint, J. W.C.</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2023</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.socscimed.2022.115430">Stepping into the shoes of the policy maker: Results of a Participatory Value Evaluation for the Dutch long term COVID-19 strategy</a></div>
#     <div>Mouter, Niek, Jara, Karen Trujillo, Hernandez, Jose Ignacio, Kroesen, Maarten, de Vries, Martijn, Geijsen, Tom, Kroese, Floor, Uiters, Ellen, de Bruin, Marijn</div>
#     <div><b class="journal-name">Social Science and Medicine</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.10.011">Modeling the effect of real-time crowding information (RTCI) on passenger distribution in trains</a></div>
#     <div>Peftitsi, Soumela, Jenelius, Erik, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trip.2022.100724">Attitude changes, modelling travel behaviour, and ex ante project evaluations</a></div>
#     <div>van Wee, Bert, Kroesen, Maarten</div>
#     <div><b class="journal-name">Transportation Research Interdisciplinary Perspectives</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2022.100358">Decision Field Theory: Equivalence with probit models and guidance for identifiability</a></div>
#     <div>Szép, Teodóra, van Cranenburgh, Sander, Chorus, Caspar G.</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trb.2022.09.009">A General Framework to Forecast the Adoption of Novel Products: A Case of Autonomous Vehicles</a></div>
#     <div>Dubey, Subodh, Sharma, Ishant, Mishra, Sabyasachee, Cats, Oded, Bansal, Prateek</div>
#     <div><b class="journal-name">Transportation Research Part B: Methodological</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1145/3560107.3560122">Perceived challenges and opportunities of machine learning applications in governmental organisations: an interview-based exploration in the Netherlands</a></div>
#     <div>Delfos, Jeroen, Zuiderwijk, Anneke, Van Cranenburgh, Sander, Chorus, Caspar</div>
#     <div><b class="journal-name">ACM International Conference Proceeding Series</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.08.005">Identifying and visualizing operational bottlenecks and Quick win opportunities for improving bus performance in public transport systems</a></div>
#     <div>Garrido-Valenzuela, Francisco, Cruz, Diego, Dragicevic, Marina, Schmidt, Alejandro, Moya, Jaime, Tamblay, Sebastián, Herrera, Juan C., Muñoz, Juan C.</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tbs.2022.08.002">Willingness to use night trains for long-distance travel</a></div>
#     <div>Heufke Kantelaar, Martijn, Molin, Eric, Cats, Oded, Donners, Barth, Wee, Bert van</div>
#     <div><b class="journal-name">Travel Behaviour and Society</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.ejor.2021.11.041">How to split the costs and charge the travellers sharing a ride? aligning system's optimum with users’ equilibrium</a></div>
#     <div>Fielbaum, Andres, Kucharski, Rafał, Cats, Oded, Alonso-Mora, Javier</div>
#     <div><b class="journal-name">European Journal of Operational Research</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2022.103783">Ride acceptance behaviour of ride-sourcing drivers</a></div>
#     <div>Ashkrof, Peyman, Homem de Almeida Correia, Gonçalo, Cats, Oded, van Arem, Bart</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cities.2022.103773">Voting with one's feet: Unraveling urban centers attraction using visiting frequency</a></div>
#     <div>Cats, Oded, Ferranti, Francesco</div>
#     <div><b class="journal-name">Cities</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.06.003">Inferring modality styles by revealing mode choice heterogeneity in response to weather conditions</a></div>
#     <div>Faber, R. M., Jonkeren, O., de Haas, M. C., Molin, E. J.E., Kroesen, M.</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tbs.2022.02.004">Does commute duration attenuate the effect of travel mode choice on commute satisfaction?</a></div>
#     <div>De Vos, Jonas, Le, Huyen T.K., Kroesen, Maarten</div>
#     <div><b class="journal-name">Travel Behaviour and Society</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2022.103394">Shifting to more sustainable mobility styles: A latent transition approach</a></div>
#     <div>Haustein, Sonja, Kroesen, Maarten</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.3389/fpsyg.2022.817860">Why Are General Moral Values Poor Predictors of Concrete Moral Behavior in Everyday Life? A Conceptual Analysis and Empirical Study</a></div>
#     <div>van den Berg, Tom Gerardus Constantijn, Kroesen, Maarten, Chorus, Caspar Gerard</div>
#     <div><b class="journal-name">Frontiers in Psychology</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.rtbm.2022.100816">Unravelling individual mobility temporal patterns using longitudinal smart card data</a></div>
#     <div>Cats, Oded, Ferranti, Francesco</div>
#     <div><b class="journal-name">Research in Transportation Business and Management</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1371/journal.pone.0269682">Simulating two-sided mobility platforms with MaaSSim</a></div>
#     <div>Kucharski, Rafał, Cats, Oded</div>
#     <div><b class="journal-name">PLoS ONE</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2022.103379">Understanding how accessibility influences health via active travel: Results from a structural equation model</a></div>
#     <div>Kroesen, Maarten, van Wee, Bert</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/TITS.2021.3055640">An Automated Detection Framework for Multiple Highway Bottleneck Activations</a></div>
#     <div>Nguyen, Tin T., Calvert, Simeon C., Vu, Hai L., Van Lint, Hans</div>
#     <div><b class="journal-name">IEEE Transactions on Intelligent Transportation Systems</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cstp.2022.03.007">Impact of introducing a metro line on urban bus services</a></div>
#     <div>Gadepalli, Ravi, Gumireddy, Sushmitha, Bhamidipati, Srirama, Cats, Oded</div>
#     <div><b class="journal-name">Case Studies on Transport Policy</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-021-10195-3">E-bike user groups and substitution effects: evidence from longitudinal travel data in the Netherlands</a></div>
#     <div>de Haas, Mathijs, Kroesen, Maarten, Chorus, Caspar, Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.3171/2021.8.SPINE21995">Patient preferences for treatment of lumbar disc herniation: a discrete choice experiment</a></div>
#     <div>Gadjradj, Pravesh S., Smeele, Nicholas V.R., de Jong, Mandy, Depauw, Paul R.A.M., van Tulder, Maurits W., de Bekker-Grob, Esther W., Harhangi, Biswadjiet S.</div>
#     <div><b class="journal-name">Journal of Neurosurgery: Spine</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/TITS.2020.3041151">Timetable Recovery After Disturbances in Metro Operations: An Exact and Efficient Solution</a></div>
#     <div>Gkiotsalitis, Konstantinos, Cats, Oded</div>
#     <div><b class="journal-name">IEEE Transactions on Intelligent Transportation Systems</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.03.027">Traveller behaviour in public transport in the early stages of the COVID-19 pandemic in the Netherlands</a></div>
#     <div>Shelat, Sanmay, Cats, Oded, van Cranenburgh, Sander</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2022.03.005">Train travel in corona time: Safety perceptions of and support for policy measures</a></div>
#     <div>Molin, Eric, Kroesen, Maarten</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trb.2022.02.007">A multinomial probit model with Choquet integral and attribute cut-offs</a></div>
#     <div>Dubey, Subodh, Cats, Oded, Hoogendoorn, Serge, Bansal, Prateek</div>
#     <div><b class="journal-name">Transportation Research Part B: Methodological</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-021-10183-7">Network design for line-based autonomous bus services</a></div>
#     <div>Hatzenbühler, Jonas, Cats, Oded, Jenelius, Erik</div>
#     <div><b class="journal-name">Transportation</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.ijtst.2021.02.002">Quantification and control of disruption propagation in multi-level public transport networks</a></div>
#     <div>Yap, Menno, Cats, Oded, Törnquist Krasemann, Johanna, van Oort, Niels, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">International Journal of Transportation Science and Technology</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1371/journal.pone.0264805">Analysing the impact of COVID-19 risk perceptions on route choice behaviour in train networks</a></div>
#     <div>Shelat, Sanmay, Van De Wiel, Thijs, Molin, Eric, van Lint, J. W.C., Cats, Oded</div>
#     <div><b class="journal-name">PLoS ONE</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2021.100340">Choice modelling in the age of machine learning - Discussion paper</a></div>
#     <div>van Cranenburgh, Sander, Wang, Shenhao, Vij, Akshay, Pereira, Francisco, Walker, Joan</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/TITS.2020.3028804">Bayesian Route Choice Inference to Address Missed Bluetooth Detections</a></div>
#     <div>Garrido-Valenzuela, Francisco, Raveau, Sebastian, Herrera, Juan C.</div>
#     <div><b class="journal-name">IEEE Transactions on Intelligent Transportation Systems</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2021.10.025">Working from home during the corona-crisis is associated with higher subjective well-being for women with long (pre-corona) commutes</a></div>
#     <div>Kroesen, Maarten</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2022.2140022">The shareability potential of ride-pooling under alternative spatial demand patterns</a></div>
#     <div>Soza-Parra, Jaime, Kucharski, Rafał, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jpubtr.2022.100036">Analysis and prediction of ridership impacts during planned public transport disruptions</a></div>
#     <div>Yap, Menno, Cats, Oded</div>
#     <div><b class="journal-name">Journal of Public Transportation</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/01441647.2021.1977415">Headway variability in public transport: a review of metrics, determinants, effects for quality of service and control strategies</a></div>
#     <div>Tirachini, Alejandro, Godachevich, Javiera, Cats, Oded, Muñoz, Juan Carlos, Soza-Parra, Jaime</div>
#     <div><b class="journal-name">Transport Reviews</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/21680566.2021.2024917">Evolution of labour supply in ridesourcing</a></div>
#     <div>de Ruijter, Arjan, Cats, Oded, Kucharski, Rafal, van Lint, Hans</div>
#     <div><b class="journal-name">Transportmetrica B</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1371/journal.pone.0262496">Beyond the dichotomy: How ride-hailing competes with and complements public transport</a></div>
#     <div>Cats, Oded, Kucharski, Rafal, Danda, Santosh Rao, Yap, Menno</div>
#     <div><b class="journal-name">PLoS ONE</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/03081060.2021.2017214">On the scalability of private and pooled on-demand services for urban mobility in Amsterdam</a></div>
#     <div>Narayan, Jishnu, Cats, Oded, van Oort, Niels, Hoogendoorn, Serge Paul</div>
#     <div><b class="journal-name">Transportation Planning and Technology</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2021.1896593">Optimal frequency setting of metro services in the age of COVID-19 distancing measures</a></div>
#     <div>Gkiotsalitis, Konstantinos, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2022</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1038/s41598-021-86704-2">Modelling virus spreading in ride-pooling networks</a></div>
#     <div>Kucharski, Rafał, Cats, Oded, Sienkiewicz, Julian</div>
#     <div><b class="journal-name">Scientific Reports</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2021.103450">A review of public transport transfer coordination at the tactical planning phase</a></div>
#     <div>Liu, Tao, Cats, Oded, Gkiotsalitis, Konstantinos</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1186/s12904-021-00716-3">Using natural language processing to explore heterogeneity in moral terminology in palliative care consultations</a></div>
#     <div>van den Broek-Altenburg, Eline, Gramling, Robert, Gothard, Kelly, Kroesen, Maarten, Chorus, Caspar</div>
#     <div><b class="journal-name">BMC Palliative Care</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2021.100307">Estimating decision rule differences between ‘best’ and ‘worst’ choices in a sequential best worst discrete choice experiment</a></div>
#     <div>Geržinič, Nejc, van Cranenburgh, Sander, Cats, Oded, Lancsar, Emily, Chorus, Caspar</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/MITS.2019.2926278">Gaps in the Control of Automated Vehicles on Roads</a></div>
#     <div>Calvert, Simeon C., Van Arem, Bart, Heikoop, Daniel D., Hagenzieker, Marjan, Mecacci, Giulio, De Sio, Filippo Santoni</div>
#     <div><b class="journal-name">IEEE Intelligent Transportation Systems Magazine</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2021.103401">Simulation of fixed versus on-demand station-based feeder operations</a></div>
#     <div>Leffler, David, Burghout, Wilco, Jenelius, Erik, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.artmed.2021.102190">A healthy debate: Exploring the views of medical doctors on the ethics of artificial intelligence</a></div>
#     <div>Martinho, Andreia, Kroesen, Maarten, Chorus, Caspar</div>
#     <div><b class="journal-name">Artificial Intelligence in Medicine</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tbs.2021.07.003">The role of travel-related reasons for location choice in residential self-selection</a></div>
#     <div>Faber, Roel, Merkies, Raimbard, Damen, Wouter, Oirbans, Leonard, Massa, Davide, Kroesen, Maarten, Molin, Eric</div>
#     <div><b class="journal-name">Travel Behaviour and Society</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-020-10139-3">An artificial neural network based method to uncover the value-of-travel-time distribution</a></div>
#     <div>van Cranenburgh, Sander, Kouwenhoven, Marco</div>
#     <div><b class="journal-name">Transportation</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2021.103159">Multi-modal network evolution in polycentric regions</a></div>
#     <div>Cats, Oded, Birch, Nigel</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tbs.2021.07.009">Quantifying travellers’ evaluation of waiting time uncertainty in public transport networks</a></div>
#     <div>Shelat, Sanmay, Cats, Oded, van Lint, J. W.C.</div>
#     <div><b class="journal-name">Travel Behaviour and Society</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jth.2021.101113">Causal relations between body-mass index, self-rated health and active travel: An empirical study based on longitudinal data</a></div>
#     <div>de Haas, Mathijs, Kroesen, Maarten, Chorus, Caspar, Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Journal of Transport and Health</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.ress.2021.107629">Quantifying the cascading effects of passenger delays</a></div>
#     <div>Cats, Oded, Hijner, Anne Mijntje</div>
#     <div><b class="journal-name">Reliability Engineering and System Safety</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-020-10116-w">Relocating shared automated vehicles under parking constraints: assessing the impact of different strategies for on-street parking</a></div>
#     <div>Winter, Konstanze, Cats, Oded, Martens, Karel, van Arem, Bart</div>
#     <div><b class="journal-name">Transportation</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-020-10109-9">Predicting disruptions and their passenger delay impacts for public transport stops</a></div>
#     <div>Yap, Menno, Cats, Oded</div>
#     <div><b class="journal-name">Transportation</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-020-10110-2">What are the determinants of the willingness to share rides in pooled on-demand services?</a></div>
#     <div>Alonso-González, María J., Cats, Oded, van Oort, Niels, Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2021.103143">Why did you predict that? Towards explainable artificial neural networks for travel demand analysis</a></div>
#     <div>Alwosheel, Ahmad, van Cranenburgh, Sander, Chorus, Caspar G.</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/MT-ITS49943.2021.9529271">Quantifying the hierarchy of public transport networks</a></div>
#     <div>Buijtenweg, Abel, Verma, Trivik, Cats, Oded, Donners, Barth, Wang, Huijuan</div>
#     <div><b class="journal-name">2021 7th International Conference on Models and Technologies for Intelligent Transportation Systems, MT-ITS 2021</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/MT-ITS49943.2021.9529310">The potential of real-time crowding information in reducing bus bunching under different network saturation levels</a></div>
#     <div>Drabicki, Arkadiusz, Cats, Oded, Kucharski, Rafał</div>
#     <div><b class="journal-name">2021 7th International Conference on Models and Technologies for Intelligent Transportation Systems, MT-ITS 2021</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jocm.2021.100286">A day in the life with an automated vehicle: Empirical analysis of data from an interactive stated activity-travel survey</a></div>
#     <div>Pudāne, Baiba, van Cranenburgh, Sander, Chorus, Caspar G.</div>
#     <div><b class="journal-name">Journal of Choice Modelling</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11023-021-09556-9">Computer Says I Don’t Know: An Empirical Approach to Capture Moral Uncertainty in Artificial Intelligence</a></div>
#     <div>Martinho, Andreia, Kroesen, Maarten, Chorus, Caspar</div>
#     <div><b class="journal-name">Minds and Machines</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2021.04.010">Charging infrastructure roll-out strategies for large scale introduction of electric vehicles in urban areas: An agent-based simulation study</a></div>
#     <div>Wolbertus, Rick, van den Hoed, Robert, Kroesen, Maarten, Chorus, Caspar</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2021.103087">A holding control strategy for diverging bus lines</a></div>
#     <div>Laskaris, Georgios, Cats, Oded, Jenelius, Erik, Rinaldi, Marco, Viti, Francesco</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2021.02.007">Taking the path less travelled: Valuation of denied boarding in crowded public transport systems</a></div>
#     <div>Yap, Menno, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tranpol.2021.03.001">Public transport fare elasticities from smartcard data: Evidence from a natural experiment</a></div>
#     <div>Kholodov, Yaroslav, Jenelius, Erik, Cats, Oded, van Oort, Niels, Mouter, Niek, Cebecauer, Matej, Vermeulen, Alex</div>
#     <div><b class="journal-name">Transport Policy</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cose.2020.102132">Investigating the effect of security and privacy on IoT device purchase behaviour</a></div>
#     <div>Ho-Sam-Sooi, Nick, Pieters, Wolter, Kroesen, Maarten</div>
#     <div><b class="journal-name">Computers and Security</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2021.102980">Examining circuity of urban transit networks from an equity perspective</a></div>
#     <div>Dixit, Malvika, Chowdhury, Subeh, Cats, Oded, Brands, Ties, van Oort, Niels, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2020.1809547">Modelling the effects of real-time crowding information in urban public transport systems</a></div>
#     <div>Drabicki, Arkadiusz, Kucharski, Rafał, Cats, Oded, Szarata, Andrzej</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2020.11.008">Parking space for shared automated vehicles: How less can be more</a></div>
#     <div>Winter, Konstanze, Cats, Oded, Martens, Karel, van Arem, Bart</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.inffus.2020.08.009">An active opinion dynamics model: the gap between the voting result and group opinion</a></div>
#     <div>Jiao, Yiru, Li, Yongli</div>
#     <div><b class="journal-name">Information Fusion</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.mathsocsci.2020.10.002">Obfuscation maximization-based decision-making: Theory, methodology and first empirical evidence</a></div>
#     <div>Chorus, Caspar, van Cranenburgh, Sander, Daniel, Aemiro Melkamu, Sandorf, Erlend Dancke, Sobhani, Anae, Szép, Teodóra</div>
#     <div><b class="journal-name">Mathematical Social Sciences</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/21680566.2021.1939808">Evaluating crowding in individual train cars using a dynamic transit assignment model</a></div>
#     <div>Peftitsi, Soumela, Jenelius, Erik, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica B</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.18757/ejtir.2021.21.2.5354">How to ensure control of cooperative vehicle and truck platoons using meaningful human control</a></div>
#     <div>Calvert, Simeon C., Mecacci, Giulio, Heikoop, Daniel D., Janssen, Robbert</div>
#     <div><b class="journal-name">European Journal of Transport and Infrastructure Research</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2020.1819910">Fleet size determination for a mixed private and pooled on-demand system with elastic demand</a></div>
#     <div>Narayan, Jishnu, Cats, Oded, van Oort, Niels, Hoogendoorn, Serge Paul</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/None">Public transport network resilience</a></div>
#     <div>Yap, Menno, Cats, Oded</div>
#     <div><b class="journal-name">Handbook of Public Transport Research</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/01441647.2020.1857886">Public transport planning adaption under the COVID-19 pandemic crisis: literature review of research needs and directions</a></div>
#     <div>Gkiotsalitis, Konstantinos, Cats, Oded</div>
#     <div><b class="journal-name">Transport Reviews</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/23249935.2020.1829170">If you are late, everyone is late: late passenger arrival and ride-pooling systems' performance</a></div>
#     <div>Kucharski, Rafał, Fielbaum, Andres, Alonso-Mora, Javier, Cats, Oded</div>
#     <div><b class="journal-name">Transportmetrica A: Transport Science</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tre.2020.102176">At-stop control measures in public transport: Literature review and research agenda</a></div>
#     <div>Gkiotsalitis, K., Cats, O.</div>
#     <div><b class="journal-name">Transportation Research Part E: Logistics and Transportation Review</b>, 2021</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/01441647.2020.1862355">Ethical issues in focus by the autonomous vehicles industry</a></div>
# ...
#     <div>Luo, Ding, Cats, Oded, van Lint, Hans</div>
#     <div><b class="journal-name">Transportation</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1049/iet-its.2019.0742">Cooperative adaptive cruise control and intelligent traffic signal interaction: A field operational test with platooning on a suburban arterial in real traffic</a></div>
#     <div>Calvert, Simeon C., van Arem, Bart</div>
#     <div><b class="journal-name">IET Intelligent Transport Systems</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.rtbm.2020.100516">Understanding ride-sourcing drivers' behaviour and preferences: Insights from focus groups analysis</a></div>
#     <div>Ashkrof, Peyman, Correia, Gonçalo Homem de Almeida, Cats, Oded, van Arem, Bart</div>
#     <div><b class="journal-name">Research in Transportation Business and Management</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jtrangeo.2020.102890">Fair accessibility – Operationalizing the distributional effects of policy interventions</a></div>
#     <div>Rubensson, Isak, Susilo, Yusak, Cats, Oded</div>
#     <div><b class="journal-name">Journal of Transport Geography</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2020.102850">A compact and scalable representation of network traffic dynamics using shapes and its applications</a></div>
#     <div>Krishnakumari, Panchamy, Cats, Oded, van Lint, Hans</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s10902-019-00200-z">Vacations Over the Years: A Cross-Lagged Panel Analysis of Tourism Experiences and Subjective Well-Being in the Netherlands</a></div>
#     <div>Mitas, Ondrej, Kroesen, Maarten</div>
#     <div><b class="journal-name">Journal of Happiness Studies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1186/s12544-020-00420-y">Identifying user classes for shared and automated mobility services</a></div>
#     <div>Winter, Konstanze, Cats, Oded, Martens, Karel, van Arem, Bart</div>
#     <div><b class="journal-name">European Transport Research Review</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/FISTS46898.2020.9264869">A practitioner's View of Driver Training for automated driving from Driving Examiners: A Focus group Discussion</a></div>
#     <div>Heikoop, D. D., Calvert, S. C., Mecacci, G., Hagenzieker, M. P.</div>
#     <div><b class="journal-name">2020 Forum on Integrated and Sustainable Transportation Systems, FISTS 2020</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/TITS.2019.2941847">Robust Network-Wide Bus Scheduling with Transfer Synchronizations</a></div>
#     <div>Gkiotsalitis, Konstantinos, Eikenbroek, Oskar A.L., Cats, Oded</div>
#     <div><b class="journal-name">IEEE Transactions on Intelligent Transportation Systems</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.retrec.2020.100910">Impacts of replacing a fixed public transport line by a demand responsive transport system: Case study of a rural area in Amsterdam</a></div>
#     <div>Coutinho, Felipe Mariz, van Oort, Niels, Christoforou, Zoi, Alonso-González, María J., Cats, Oded, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Research in Transportation Economics</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trf.2020.08.017">Does morality predict aggressive driving? A conceptual analysis and exploratory empirical investigation</a></div>
#     <div>van den Berg, Tom G.C., Kroesen, Maarten, Chorus, Caspar G.</div>
#     <div><b class="journal-name">Transportation Research Part F: Traffic Psychology and Behaviour</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.futures.2020.102610">Stakeholders’ perspectives on future electric vehicle charging infrastructure developments</a></div>
#     <div>Wolbertus, Rick, Jansen, Steven, Kroesen, Maarten</div>
#     <div><b class="journal-name">Futures</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trb.2020.07.011">A generic multi-scale framework for microscopic traffic simulation part II – Anticipation Reliance as compensation mechanism for potential task overload</a></div>
#     <div>Calvert, Simeon C., Schakel, Wouter J., van Lint, J. W.C.</div>
#     <div><b class="journal-name">Transportation Research Part B: Methodological</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/ITSC45102.2020.9294370">A methodology for prediction accuracy assessment of intelligent traffic signal control algorithms with SPaT messages</a></div>
#     <div>Soni, S., Calvert, S. C.</div>
#     <div><b class="journal-name">2020 IEEE 23rd International Conference on Intelligent Transportation Systems, ITSC 2020</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/ITSC45102.2020.9294342">Unraveling the Hierarchy of Public Transport Networks</a></div>
#     <div>Wang, Ziyulong, Luo, Ding, Cats, Oded, Verma, Trivik</div>
#     <div><b class="journal-name">2020 IEEE 23rd International Conference on Intelligent Transportation Systems, ITSC 2020</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1177/0361198120945319">Estimating the Safety Effects of Congestion Warning Systems using Carriageway Aggregate Data</a></div>
#     <div>van Lint, Hans, Nguyen, Tin Thien, Krishnakumari, Panchamy, Calvert, Simeon C., Schuurman, Henk, Schreuder, Marco</div>
#     <div><b class="journal-name">Transportation Research Record</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trb.2020.06.006">Exact matching of attractive shared rides (ExMAS) for system-wide strategic evaluations</a></div>
#     <div>Kucharski, Rafał, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part B: Methodological</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cstp.2020.05.001">Designing bus rapid transit systems: Lessons on service reliability and operations</a></div>
#     <div>Ishaq, Robert, Cats, Oded</div>
#     <div><b class="journal-name">Case Studies on Transport Policy</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.cstp.2020.05.011">The impact and potential of cooperative and automated driving for intelligent traffic signal corridors: A field-operational-test and simulation experiment</a></div>
#     <div>Calvert, S. C., Klunder, G., Steendijk, J. L.L., Snelder, M.</div>
#     <div><b class="journal-name">Case Studies on Transport Policy</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-019-10060-4">Linear, non-linear, bi-directional? Testing the nature of the relationship between mobility and satisfaction with life</a></div>
#     <div>Delbosc, Alexa, Kroesen, Maarten, van Wee, Bert, de Haas, Mathijs</div>
#     <div><b class="journal-name">Transportation</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2020.102704">Estimation of metro network passenger delay from individual trajectories</a></div>
#     <div>Krishnakumari, Panchamy, Cats, Oded, van Lint, Hans</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2020.06.019">Transitioning towards the deployment of line-based autonomous buses: Consequences for service frequency and vehicle capacity</a></div>
#     <div>Hatzenbühler, Jonas, Cats, Oded, Jenelius, Erik</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-019-09978-6">Cycling culture and socialisation: modelling the effect of immigrant origin on cycling in Denmark and the Netherlands</a></div>
#     <div>Haustein, Sonja, Kroesen, Maarten, Mulalic, Ismir</div>
#     <div><b class="journal-name">Transportation</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1007/s11116-019-09975-9">Latent classes of daily mobility patterns: the relationship with attitudes towards modes</a></div>
#     <div>Ton, Danique, Zomer, Lara Britt, Schneider, Florian, Hoogendoorn-Lanser, Sascha, Duives, Dorine, Cats, Oded, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1080/1463922X.2019.1697390">A human centric framework for the analysis of automated driving systems based on meaningful human control</a></div>
#     <div>Calvert, Simeon C., Heikoop, Daniël D., Mecacci, Giulio, van Arem, Bart</div>
#     <div><b class="journal-name">Theoretical Issues in Ergonomics Science</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.physa.2020.124317">Metropolitan rail network robustness</a></div>
#     <div>Cats, Oded, Krishnakumari, Panchamy</div>
#     <div><b class="journal-name">Physica A: Statistical Mechanics and its Applications</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1109/TITS.2019.2912430">Heuristic Coarsening for Generating Multiscale Transport Networks</a></div>
#     <div>Krishnakumari, Panchamy, Cats, Oded, Van Lint, Hans</div>
#     <div><b class="journal-name">IEEE Transactions on Intelligent Transportation Systems</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tranpol.2020.03.013">Is flat fare fair? Equity impact of fare scheme change</a></div>
#     <div>Rubensson, Isak, Susilo, Yusak, Cats, Oded</div>
#     <div><b class="journal-name">Transport Policy</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2020.102621">Value of time and reliability for urban pooled on-demand services</a></div>
#     <div>Alonso-González, María J., van Oort, Niels, Cats, Oded, Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2020.102631">Integrated route choice and assignment model for fixed and flexible public transport systems</a></div>
#     <div>Narayan, Jishnu, Cats, Oded, van Oort, Niels, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2020.102643">Corrigendum to “A generic multi-level framework for microscopic traffic simulation with automated vehicles in mixed traffic” [Transport. Res. Part C: Emerg. Technol. 110 (2020) 291–311] (Transportation Research Part C (2020) 110 (291–311), (S0968090X19304322), (10.1016/j.trc.2019.11.019))</a></div>
#     <div>Calvert, S. C., van Arem, B., van Lint, J. W.C.</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.trc.2019.05.014">A data driven method for OD matrix estimation</a></div>
#     <div>Krishnakumari, Panchamy, van Lint, Hans, Djukic, Tamara, Cats, Oded</div>
#     <div><b class="journal-name">Transportation Research Part C: Emerging Technologies</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2020.01.014">A new perspective on the role of attitudes in explaining travel behavior: A psychological network model</a></div>
#     <div>Kroesen, Maarten, Chorus, Caspar</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.ejtl.2020.100003">Special issue on “Modelling passenger flows in multi-modal public transport systems”</a></div>
#     <div>Cats, Oded, Scarinci, Riccardo</div>
#     <div><b class="journal-name">EURO Journal on Transportation and Logistics</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.jth.2020.100844">Does active travel make people healthier, or are healthy people more inclined to travel actively?</a></div>
#     <div>Kroesen, Maarten, De Vos, Jonas</div>
#     <div><b class="journal-name">Journal of Transport and Health</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2019.10.017">Does conducting activities while traveling reduce the value of time? Evidence from a within-subjects choice experiment</a></div>
#     <div>Molin, Eric, Adjenughwure, Kingsley, de Bruyn, Menno, Cats, Oded, Warffemius, Pim</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2019.12.032">A passenger-pedestrian model to assess platform and train usage from automated data</a></div>
#     <div>Hänseler, Flurin S., van den Heuvel, Jeroen P.A., Cats, Oded, Daamen, Winnie, Hoogendoorn, Serge P.</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2019.11.022">Drivers and barriers in adopting Mobility as a Service (MaaS) – A latent class cluster analysis of attitudes</a></div>
#     <div>Alonso-González, María J., Hoogendoorn-Lanser, Sascha, van Oort, Niels, Cats, Oded, Hoogendoorn, Serge</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li>
#   <li class="publication-list-item">
#     <div class="publication-title"><a href="https://doi.org/10.1016/j.tra.2019.12.027">The experienced mode choice set and its determinants: Commuting trips in the Netherlands</a></div>
#     <div>Ton, Danique, Bekhor, Shlomo, Cats, Oded, Duives, Dorine C., Hoogendoorn-Lanser, Sascha, Hoogendoorn, Serge P.</div>
#     <div><b class="journal-name">Transportation Research Part A: Policy and Practice</b>, 2020</div>
#   </li></ul>

# %%
import shutil
shutil.copy('_publications.html', '../publications.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_29469/3199587598.py in <module>
#       1 import shutil
# ----> 2 shutil.copy('_automation/_publications.html', 'publications.html')
#
# ~/anaconda3/lib/python3.9/shutil.py in copy(src, dst, follow_symlinks)
#     425     if os.path.isdir(dst):
#     426         dst = os.path.join(dst, os.path.basename(src))
# --> 427     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428     copymode(src, dst, follow_symlinks=follow_symlinks)
#     429     return dst
#
# ~/anaconda3/lib/python3.9/shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc:
#     265             try:
#     266                 with open(dst, 'wb') as fdst:
#
# FileNotFoundError: [Errno 2] No such file or directory: '_automation/_publications.html'
